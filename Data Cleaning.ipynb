# %% [markdown]
# ## Description:
# ### This dataset contains data about street trees and their features such as  species, diameter and perception of health etc.

# %%
import pandas as pd
import numpy as np
import klib
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns', None)
df = pd.read_csv(r'C:\Users\Yash\Downloads\2015_Street_Tree_Census_-_Tree_Data (1).csv')
df.head()
# Out:
#    tree_id  block_id  created_at  tree_dbh  stump_diam curb_loc status health  \
# 0   180683    348711  08/27/2015         3           0   OnCurb  Alive   Fair
# 1   200540    315986  09/03/2015        21           0   OnCurb  Alive   Fair
# 2   204026    218365  09/05/2015         3           0   OnCurb  Alive   Good
# 3   204337    217969  09/05/2015        10           0   OnCurb  Alive   Good
# 4   189565    223043  08/30/2015        21           0   OnCurb  Alive   Good
#
#                             spc_latin       spc_common steward guards  \
# 0                         Acer rubrum        red maple    None   None
# 1                   Quercus palustris          pin oak    None   None
# 2  Gleditsia triacanthos var. inermis      honeylocust    1or2   None
# 3  Gleditsia triacanthos var. inermis      honeylocust    None   None
# 4                     Tilia americana  American linden    None   None
#
#    sidewalk         user_type problems root_stone root_grate root_other  \
# ...

# %%
df.shape
# Out:
# (683788, 45)

# %%
df.describe()
# Out:
#              tree_id       block_id       tree_dbh     stump_diam  \
# count  683788.000000  683788.000000  683788.000000  683788.000000
# mean   365205.011085  313793.096236      11.279787       0.432463
# std    208122.092902  114839.024312       8.723042       3.290241
# min         3.000000  100002.000000       0.000000       0.000000
# 25%    186582.750000  221556.000000       4.000000       0.000000
# 50%    366214.500000  319967.000000       9.000000       0.000000
# 75%    546170.250000  404624.000000      16.000000       0.000000
# max    722694.000000  999999.000000     450.000000     140.000000
#
#             postcode  community board       borocode       cncldist  \
# count  683788.000000    683788.000000  683788.000000  683788.000000
# mean    10916.246044       343.505404       3.358500      29.943181
# std       651.553364       115.740601       1.166746      14.328531
# min        83.000000       101.000000       1.000000       1.000000
# ...

# %%
df.columns
# Out:
# Index(['tree_id', 'block_id', 'created_at', 'tree_dbh', 'stump_diam',
#        'curb_loc', 'status', 'health', 'spc_latin', 'spc_common', 'steward',
#        'guards', 'sidewalk', 'user_type', 'problems', 'root_stone',
#        'root_grate', 'root_other', 'trunk_wire', 'trnk_light', 'trnk_other',
#        'brch_light', 'brch_shoe', 'brch_other', 'address', 'postcode',
#        'zip_city', 'community board', 'borocode', 'borough', 'cncldist',
#        'st_assem', 'st_senate', 'nta', 'nta_name', 'boro_ct', 'state',
#        'latitude', 'longitude', 'x_sp', 'y_sp', 'council district',
#        'census tract', 'bin', 'bbl'],
#       dtype='object')

# %%
df = klib.data_cleaning(df)
# Out:
# Shape of cleaned data: (683788, 44) - Remaining NAs: 253521
#
#
# Dropped rows: 0
#      of which 0 duplicates. (Rows (first 150 shown): [])
#
# Dropped columns: 1
#      of which 1 single valued.     Columns: ['state']
# Dropped missing values: 0
# Reduced memory by at least: 173.41 MB (-73.87%)

# %% [markdown]
# ## Deleting unwanted cols

# %%
df2 = df[['tree_id', 'tree_dbh', 'stump_diam',
       'curb_loc', 'status', 'health', 'spc_latin', 'steward',
       'guards', 'sidewalk', 'problems', 'root_stone',
       'root_grate', 'root_other', 'trunk_wire', 'trnk_light', 'trnk_other',
       'brch_light', 'brch_shoe', 'brch_other', ]]
df2.head(10)
# Out:
#    tree_id  tree_dbh  stump_diam        curb_loc status health  \
# 0   180683         3           0          OnCurb  Alive   Fair
# 1   200540        21           0          OnCurb  Alive   Fair
# 2   204026         3           0          OnCurb  Alive   Good
# 3   204337        10           0          OnCurb  Alive   Good
# 4   189565        21           0          OnCurb  Alive   Good
# 5   190422        11           0          OnCurb  Alive   Good
# 6   190426        11           0          OnCurb  Alive   Good
# 7   208649         9           0          OnCurb  Alive   Good
# 8   209610         6           0          OnCurb  Alive   Good
# 9   192755        21           0  OffsetFromCurb  Alive   Fair
#
#                             spc_latin steward   guards  sidewalk     problems  \
# 0                         Acer rubrum    None     None  NoDamage         None
# 1                   Quercus palustris    None     None    Damage       Stones
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 683788 entries, 0 to 683787
# Data columns (total 20 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   tree_id     683788 non-null  int32
#  1   tree_dbh    683788 non-null  int16
#  2   stump_diam  683788 non-null  int16
#  3   curb_loc    683788 non-null  category
#  4   status      683788 non-null  category
#  5   health      652172 non-null  category
#  6   spc_latin   652169 non-null  category
#  7   steward     652173 non-null  category
#  8   guards      652172 non-null  category
#  9   sidewalk    652172 non-null  category
#  10  problems    652124 non-null  category
#  11  root_stone  683788 non-null  category
#  12  root_grate  683788 non-null  category
#  13  root_other  683788 non-null  category
#  14  trunk_wire  683788 non-null  category
#  15  trnk_light  683788 non-null  category
#  16  trnk_other  683788 non-null  category
# ...

# %%
df2.isna().sum()
# Out:
# tree_id           0
# tree_dbh          0
# stump_diam        0
# curb_loc          0
# status            0
# health        31616
# spc_latin     31619
# steward       31615
# guards        31616
# sidewalk      31616
# problems      31664
# root_stone        0
# root_grate        0
# root_other        0
# trunk_wire        0
# trnk_light        0
# trnk_other        0
# brch_light        0
# brch_shoe         0
# brch_other        0
# dtype: int64

# %%
df2[df2['health'].isna()]
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status health spc_latin  \
# 37       211205         0          16          OnCurb  Stump    NaN       NaN
# 57       187807         0           0          OnCurb   Dead    NaN       NaN
# 196      208322        10           0          OnCurb   Dead    NaN       NaN
# 209      209058         6           0          OnCurb   Dead    NaN       NaN
# 239      203597         0          15          OnCurb  Stump    NaN       NaN
# ...         ...       ...         ...             ...    ...    ...       ...
# 683693   156162         3           0  OffsetFromCurb   Dead    NaN       NaN
# 683695   170888         0           5          OnCurb  Stump    NaN       NaN
# 683697   177922         0          17          OnCurb  Stump    NaN       NaN
# 683698   193791         3           0          OnCurb   Dead    NaN       NaN
# 683699   172660         0           4          OnCurb  Stump    NaN       NaN
#
# ...

# %%
df2.describe()
# Out:
#              tree_id       tree_dbh     stump_diam
# count  683788.000000  683788.000000  683788.000000
# mean   365205.011085      11.279787       0.432463
# std    208122.092902       8.723042       3.290241
# min         3.000000       0.000000       0.000000
# 25%    186582.750000       4.000000       0.000000
# 50%    366214.500000       9.000000       0.000000
# 75%    546170.250000      16.000000       0.000000
# max    722694.000000     450.000000     140.000000

# %% [markdown]
# ## Checking Outliers

# %%
df2.hist(bins = 60, figsize = (20,10))
# Out:
# array([[<AxesSubplot: title={'center': 'tree_id'}>,
#         <AxesSubplot: title={'center': 'tree_dbh'}>],
#        [<AxesSubplot: title={'center': 'stump_diam'}>, <AxesSubplot: >]],
#       dtype=object)

# %%
big_tree = df2[df2['tree_dbh'] > 50]
big_tree
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status health  \
# 2405     168583       425           0          OnCurb  Alive   Good
# 3738     199546        51           0          OnCurb  Alive   Good
# 4887     139665        72           0  OffsetFromCurb  Alive   Good
# 6724     209349       122           0          OnCurb  Alive   Good
# 10083    215075       169           0          OnCurb  Alive   Good
# ...         ...       ...         ...             ...    ...    ...
# 675265   179496        52           0  OffsetFromCurb  Alive   Good
# 677954   166796        54           0          OnCurb  Alive   Good
# 679894   169501        51           0          OnCurb  Alive   Good
# 681736   179366       281           0          OnCurb  Alive   Fair
# 682788   183910       127           0          OnCurb   Dead    NaN
#
#                                  spc_latin steward guards  sidewalk  \
# 2405                       Quercus bicolor    1or2   None    Damage
# ...

# %%
p = sns.jointplot(x = 'tree_id' , y = 'tree_dbh', data = big_tree)
p.fig.set_figwidth(10)
p.fig.set_figheight(8)

# %%
df2['spc_latin'].value_counts().plot(kind ='bar', figsize = (15,8))
# Out:
# <AxesSubplot: >

# %%
df2['spc_latin'].value_counts()
# Out:
# Platanus x acerifolia                 87014
# Gleditsia triacanthos var. inermis    64264
# Pyrus calleryana                      58931
# Quercus palustris                     53185
# Acer platanoides                      34189
#                                       ...
# Pinus nigra                              37
# Pinus rigida                             33
# Maclura pomifera                         29
# Pinus sylvestris                         25
# Pinus virginiana                         10
# Name: spc_latin, Length: 132, dtype: int64

# %%
df2['status'].value_counts()
# Out:
# Alive    652173
# Stump     17654
# Dead      13961
# Name: status, dtype: int64

# %%
17654 + 13961
# Out:
# 31615

# %% [markdown]
# #### As no. of missing values in the cols are NEARLY equal to sum of stump and dead trees, we can say that health,spc_latin ,steward, guards, sidewalk data was not recorded for dead or stump trees

# %% [markdown]
# ## Finding missing values

# %%
df2.loc[(df2['status'] == 'Alive') & (df2['health'].isna())]
# Out:
#        tree_id  tree_dbh  stump_diam curb_loc status health  \
# 32889   245041        16           0   OnCurb  Alive    NaN
#
#                     spc_latin steward guards sidewalk problems root_stone  \
# 32889  Fraxinus pennsylvanica    None   None   Damage     None         No
#
#       root_grate root_other trunk_wire trnk_light trnk_other brch_light  \
# 32889         No         No         No         No         No         No
#
#       brch_shoe brch_other
# 32889        No         No

# %% [markdown]
# ## Checking for colinearity

# %%
df.corr()
# Out:
#                    tree_id  block_id  tree_dbh  stump_diam  postcode  \
# tree_id           1.000000  0.114649  0.098413    0.012563  0.199660
# block_id          0.114649  1.000000  0.002445    0.003633 -0.074176
# tree_dbh          0.098413  0.002445  1.000000   -0.169963  0.099781
# stump_diam        0.012563  0.003633 -0.169963    1.000000  0.040682
# postcode          0.199660 -0.074176  0.099781    0.040682  1.000000
# community_board   0.235266  0.359408  0.100037    0.022461  0.324896
# borocode          0.226142  0.364807  0.094372    0.020702  0.309710
# cncldist          0.149115  0.063857  0.057056    0.004629  0.169539
# st_assem         -0.209727  0.206664 -0.144429   -0.046938 -0.674876
# st_senate        -0.231528  0.193345 -0.133569   -0.040944 -0.648751
# boro_ct           0.229696  0.358776  0.097330    0.021716  0.323152
# latitude         -0.131784  0.142741 -0.034252   -0.004690 -0.106493
# longitude         0.137696 -0.009611  0.093162    0.036701  0.492576
# ...

# %% [markdown]
# ## Filling in missing values

# %%
df2.isna().sum()
# Out:
# tree_id           0
# tree_dbh          0
# stump_diam        0
# curb_loc          0
# status            0
# health        31616
# spc_latin     31619
# steward       31615
# guards        31616
# sidewalk      31616
# problems      31664
# root_stone        0
# root_grate        0
# root_other        0
# trunk_wire        0
# trnk_light        0
# trnk_other        0
# brch_light        0
# brch_shoe         0
# brch_other        0
# dtype: int64

# %%
df2['health'].value_counts()
# Out:
# Good    528850
# Fair     96504
# Poor     26818
# Name: health, dtype: int64

# %%
df2['spc_latin'].value_counts()
# Out:
# Platanus x acerifolia                 87014
# Gleditsia triacanthos var. inermis    64264
# Pyrus calleryana                      58931
# Quercus palustris                     53185
# Acer platanoides                      34189
#                                       ...
# Pinus nigra                              37
# Pinus rigida                             33
# Maclura pomifera                         29
# Pinus sylvestris                         25
# Pinus virginiana                         10
# Name: spc_latin, Length: 132, dtype: int64

# %%
df2['steward'].value_counts()
# Out:
# None       487823
# 1or2       143557
# 3or4        19183
# 4orMore      1610
# Name: steward, dtype: int64

# %%
df2['guards'].value_counts()
# Out:
# None       572306
# Helpful     51866
# Harmful     20252
# Unsure       7748
# Name: guards, dtype: int64

# %%
df2['sidewalk'].value_counts()
# Out:
# NoDamage    464978
# Damage      187194
# Name: sidewalk, dtype: int64

# %%
df2['problems'].value_counts()
# Out:
# None                                                                426280
# Stones                                                               95673
# BranchLights                                                         29452
# Stones,BranchLights                                                  17808
# RootOther                                                            11418
#                                                                      ...
# MetalGrates,WiresRope,TrunkLights                                        1
# Stones,WiresRope,TrunkLights,TrunkOther,BranchLights,BranchOther         1
# MetalGrates,TrunkOther,Sneakers                                          1
# MetalGrates,TrunkOther,BranchLights,BranchOther                          1
# WiresRope,TrunkOther,Sneakers                                            1
# Name: problems, Length: 232, dtype: int64

# %%
df2['problems'].fillna('None', inplace = True)
df2['health'].fillna('Good', inplace = True)
df2['sidewalk'].fillna('NoDamage', inplace = True)
df2['guards'].fillna('None', inplace = True)
df2['steward'].fillna('None', inplace = True)
# Out:
# C:\Users\Yash\AppData\Local\Temp\ipykernel_7624\3067719144.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['problems'].fillna('None', inplace = True)
# C:\Users\Yash\AppData\Local\Temp\ipykernel_7624\3067719144.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['health'].fillna('Good', inplace = True)
# C:\Users\Yash\AppData\Local\Temp\ipykernel_7624\3067719144.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df2.loc[df2['spc_latin'].isna()]
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status health spc_latin  \
# 37       211205         0          16          OnCurb  Stump   Good       NaN
# 57       187807         0           0          OnCurb   Dead   Good       NaN
# 196      208322        10           0          OnCurb   Dead   Good       NaN
# 209      209058         6           0          OnCurb   Dead   Good       NaN
# 239      203597         0          15          OnCurb  Stump   Good       NaN
# ...         ...       ...         ...             ...    ...    ...       ...
# 683693   156162         3           0  OffsetFromCurb   Dead   Good       NaN
# 683695   170888         0           5          OnCurb  Stump   Good       NaN
# 683697   177922         0          17          OnCurb  Stump   Good       NaN
# 683698   193791         3           0          OnCurb   Dead   Good       NaN
# 683699   172660         0           4          OnCurb  Stump   Good       NaN
#
# ...

# %%
df2['spc_latin'] = df2['spc_latin'].cat.add_categories('No Observation')
# Out:
# C:\Users\Yash\AppData\Local\Temp\ipykernel_7624\3909251553.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['spc_latin'] = df2['spc_latin'].cat.add_categories('No Observation')

# %%
df2['spc_latin'].fillna('No Observation', inplace = True)
# Out:
# C:\Users\Yash\AppData\Local\Temp\ipykernel_7624\3067451849.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['spc_latin'].fillna('No Observation', inplace = True)

# %%
df2.isna().sum()
# Out:
# tree_id       0
# tree_dbh      0
# stump_diam    0
# curb_loc      0
# status        0
# health        0
# spc_latin     0
# steward       0
# guards        0
# sidewalk      0
# problems      0
# root_stone    0
# root_grate    0
# root_other    0
# trunk_wire    0
# trnk_light    0
# trnk_other    0
# brch_light    0
# brch_shoe     0
# brch_other    0
# dtype: int64

# %%
df2.to_csv('tree_census_processed.csv', index=False)

# %%
df2.isna().sum()
# Out:
# tree_id       0
# tree_dbh      0
# stump_diam    0
# curb_loc      0
# status        0
# health        0
# spc_latin     0
# steward       0
# guards        0
# sidewalk      0
# problems      0
# root_stone    0
# root_grate    0
# root_other    0
# trunk_wire    0
# trnk_light    0
# trnk_other    0
# brch_light    0
# brch_shoe     0
# brch_other    0
# dtype: int64

# %%
df2.shape
# Out:
# (683788, 20)

# %%
df2.head()
# Out:
#    tree_id  tree_dbh  stump_diam curb_loc status health  \
# 0   180683         3           0   OnCurb  Alive   Fair
# 1   200540        21           0   OnCurb  Alive   Fair
# 2   204026         3           0   OnCurb  Alive   Good
# 3   204337        10           0   OnCurb  Alive   Good
# 4   189565        21           0   OnCurb  Alive   Good
#
#                             spc_latin steward guards  sidewalk problems  \
# 0                         Acer rubrum    None   None  NoDamage     None
# 1                   Quercus palustris    None   None    Damage   Stones
# 2  Gleditsia triacanthos var. inermis    1or2   None    Damage     None
# 3  Gleditsia triacanthos var. inermis    None   None    Damage   Stones
# 4                     Tilia americana    None   None    Damage   Stones
#
#   root_stone root_grate root_other trunk_wire trnk_light trnk_other  \
# 0         No         No         No         No         No         No
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train,y_test = train_test_split(df[:, ])

# %%
from sklearn import tree

# %%
clfTree = tree.DecisionTreeClassifier(max_depth = 4)

# %%
dot_data = tree.export_graphviz(clfTree, out_file = None, feature_names = x_train.columns, filled = True)
from IPython.display import Image
import pydotplus
graph = pydotplus.graph_from_dot_data(dot_data)
Image(graph.create_png())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 dot_data = tree.export_graphviz(clfTree, out_file = None, feature_names = x_train.columns, filled = True)
#       2 from IPython.display import Image
#       3 import pydotplus
#
# NameError: name 'x_train' is not defined
