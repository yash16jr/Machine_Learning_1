# %%
import pandas as pd

# %%
df = pd.read_csv('unicorn.csv')

# %%
df.head()
# Out:
#       Company  Valuation($B)  Date Joined        Country           City  \
# 0  ﻿ByteDance           $140   04-07-2017          China        Beijing
# 1      SpaceX           $127   12-01-2012  United States      Hawthorne
# 2       SHEIN           $100   07-03-2018          China       Shenzhen
# 3      Stripe            $95    1/23/2014  United States  San Francisco
# 4       Canva            $40   01-08-2018      Australia    Surry Hills
#
#                               Industry                Investors  \
# 0              Artificial intelligence    Sequoia Capital China
# 1                                Other            Founders Fund
# 2  E-commerce &amp; direct-to-consumer  Tiger Global Management
# 3                              Fintech          Khosla Ventures
# 4     Internet software &amp; services    Sequoia Capital China
#
#                  Unnamed: 7                 Unnamed: 8       Unnamed: 9  \
# ...

# %%
df.tail()
# Out:
#                   Company  Valuation($B)  Date Joined        Country  \
# 1199          LeadSquared             $1    6/21/2022          India
# 1200            FourKites             $1    6/21/2022  United States
# 1201          VulcanForms             $1   07-05-2022  United States
# 1202          SingleStore             $1   07-12-2022  United States
# 1203  Unstoppable Domains             $1    7/27/2022  United States
#
#                City                          Industry              Investors  \
# 1199      Bengaluru  Internet software &amp; services  Gaja Capital Partners
# 1200        Chicago                      Supply chain              logistics
# 1201     Burlington                      Supply chain              logistics
# 1202  San Francisco   Data management &amp; analytics        Google Ventures
# 1203      Las Vegas  Internet software &amp; services               Boost VC
#
#               Unnamed: 7                  Unnamed: 8              Unnamed: 9  \
# ...

# %%
df.shape
# Out:
# (1204, 12)

# %%
df.columns
# Out:
# Index(['Company', ' Valuation($B)', ' Date Joined', ' Country', ' City',
#        ' Industry', ' Investors', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11'],
#       dtype='object')

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Company              0
#  Valuation($B)       0
#  Date Joined         0
#  Country             0
#  City               17
#  Industry            0
#  Investors           1
# Unnamed: 7          57
# Unnamed: 8         148
# Unnamed: 9        1132
# Unnamed: 10       1142
# Unnamed: 11       1201
# dtype: int64

# %%
df = df[['Company', ' Valuation($B)', ' Date Joined', ' Country', ' City',
       ' Industry', ' Investors']]

# %%
df.isnull().sum()
# Out:
# Company            0
#  Valuation($B)     0
#  Date Joined       0
#  Country           0
#  City             17
#  Industry          0
#  Investors         1
# dtype: int64

# %%
df[' City'] = df[' City'].fillna('Not Available')
df[' Investors'] = df[' Investors'].fillna('Not Available')

# %%
df.isnull().sum()
# Out:
# Company           0
#  Valuation($B)    0
#  Date Joined      0
#  Country          0
#  City             0
#  Industry         0
#  Investors        0
# dtype: int64

# %%
df
# Out:
#                   Company  Valuation($B)  Date Joined        Country  \
# 0              ﻿ByteDance           $140   04-07-2017          China
# 1                  SpaceX           $127   12-01-2012  United States
# 2                   SHEIN           $100   07-03-2018          China
# 3                  Stripe            $95    1/23/2014  United States
# 4                   Canva            $40   01-08-2018      Australia
# ...                   ...            ...          ...            ...
# 1199          LeadSquared             $1    6/21/2022          India
# 1200            FourKites             $1    6/21/2022  United States
# 1201          VulcanForms             $1   07-05-2022  United States
# 1202          SingleStore             $1   07-12-2022  United States
# 1203  Unstoppable Domains             $1    7/27/2022  United States
#
#                City                             Industry  \
# 0           Beijing              Artificial intelligence
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1204 entries, 0 to 1203
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Company         1204 non-null   object
#  1    Valuation($B)  1204 non-null   object
#  2    Date Joined    1204 non-null   object
#  3    Country        1204 non-null   object
#  4    City           1204 non-null   object
#  5    Industry       1204 non-null   object
#  6    Investors      1204 non-null   object
# dtypes: object(7)
# memory usage: 66.0+ KB

# %%
df.nunique()
# Out:
# Company           1201
#  Valuation($B)     229
#  Date Joined       715
#  Country            49
#  City              283
#  Industry           16
#  Investors         584
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df[' Country'].unique()
# Out:
# array(['China', 'United States', 'Australia', 'United Kingdom', 'India',
#        'Indonesia', 'Germany', 'Turkey', 'Hong Kong', 'Seychelles',
#        'Sweden', 'Mexico', 'Estonia', 'Canada', 'South Korea',
#        'Netherlands', 'France', 'Israel', 'Finland', 'Colombia',
#        'Belgium', 'Brazil', 'Denmark', 'Switzerland', 'Lithuania',
#        'Austria', 'Ireland', 'Singapore', 'Vietnam',
#        'United Arab Emirates', 'Argentina', 'Spain', 'Japan',
#        'Luxembourg', 'Nigeria', 'Philippines', 'Croatia', 'Senegal',
#        'Malaysia', 'Bermuda', 'Norway', 'South Africa', 'Ecuador',
#        'Chile', 'Thailand', 'Czech Republic', 'Liechtenstein', 'Italy',
#        'London'], dtype=object)

# %%
df[' Country'].value_counts()
# Out:
# United States           651
# China                   172
# India                    70
# United Kingdom           49
# Germany                  29
# France                   25
# Israel                   23
# Canada                   20
# Brazil                   16
# Singapore                14
# South Korea              14
# Mexico                    8
# Australia                 8
# Indonesia                 7
# Hong Kong                 7
# Sweden                    7
# Netherlands               7
# Ireland                   6
# Switzerland               6
# Japan                     6
# Spain                     5
# Finland                   4
# Norway                    4
# Belgium                   3
# Turkey                    3
# Thailand                  3
# United Arab Emirates      3
# Colombia                  3
# Chile                     2
# Philippines               2
# South Africa              2
# Italy                     2
# Croatia                   2
# ...

# %%
plt.figure(figsize=(15,6))
sns.countplot(df[' Country'], data = df, 
             palette = 'hls')
plt.xticks(rotation = 90)
plt.show()

# %%
df[' City'].unique()
# Out:
# array(['Beijing', 'Hawthorne', 'Shenzhen', 'San Francisco', 'Surry Hills',
#        'London', 'Cary', 'Jacksonville', 'Bengaluru', 'Shanghai',
#        'Jakarta', 'Philadelphia', 'New York', 'Munich', 'Waltham',
#        'San Diego', 'Roseville', 'Changsha', 'Istanbul', 'Luohe',
#        'Cheung Sha Wan', 'Walpole', 'Victoria', 'Boston', 'Glendale',
#        'Berlin', 'Palo Alto', 'Stockholm', 'Kirkland', 'Gurugram',
#        'Lerma de Villada', 'Mountain View', 'Fremont', 'Irvine',
#        'Tallinn', 'San Jose', 'San Mateo', 'Chicago', 'Mumbai', 'Irving',
#        'Vancouver', 'Santa Clara', 'Pittsburgh', 'Seoul', 'Hangzhou',
#        'Toronto', 'Changzhou', 'Amsterdam', 'Paris', 'Los Angeles',
#        'Tel Aviv', 'Hoboken', 'Brooklyn', 'Helsinki', 'Pflugerville',
#        'Oakland', 'Bogota', 'Brussels', 'Atlanta', 'Campinas',
#        'Sao Paulo', 'Melbourne', 'Gurgaon', 'Noida', 'Bellevue',
#        'Montreal', 'Copenhagen', 'Geneva', 'Burlingame', 'Vilnius',
# ...

# %%
df[' City'].value_counts()
# Out:
# San Francisco    169
# New York         116
# Beijing           62
# Shanghai          43
# London            39
#                 ...
# Leudelange         1
# Goleta             1
# Lagos              1
# Pennsauken         1
# Las Vegas          1
# Name:  City, Length: 283, dtype: int64

# %%
df1 = df[' City'].value_counts()

# %%
df1.to_frame()
# Out:
#                 City
# San Francisco    169
# New York         116
# Beijing           62
# Shanghai          43
# London            39
# ...              ...
# Leudelange         1
# Goleta             1
# Lagos              1
# Pennsauken         1
# Las Vegas          1
#
# [283 rows x 1 columns]

# %%
df1 = df1.reset_index()

# %%
df1
# Out:
#              index   City
# 0    San Francisco    169
# 1         New York    116
# 2          Beijing     62
# 3         Shanghai     43
# 4           London     39
# ..             ...    ...
# 278     Leudelange      1
# 279         Goleta      1
# 280          Lagos      1
# 281     Pennsauken      1
# 282      Las Vegas      1
#
# [283 rows x 2 columns]

# %%
df1 = df1.rename(columns = {'index':'City', ' City':'Count'})

# %%
df1
# Out:
#               City  Count
# 0    San Francisco    169
# 1         New York    116
# 2          Beijing     62
# 3         Shanghai     43
# 4           London     39
# ..             ...    ...
# 278     Leudelange      1
# 279         Goleta      1
# 280          Lagos      1
# 281     Pennsauken      1
# 282      Las Vegas      1
#
# [283 rows x 2 columns]

# %%
plt.figure(figsize=(15,6))
sns.barplot(x = df1['City'].head(20), y = df1['Count'].head(20), data = df1, 
             palette = 'hls')
plt.xticks(rotation = 90)
plt.show()

# %%
df[' Industry'].unique()
# Out:
# array(['Artificial intelligence', 'Other',
#        'E-commerce &amp; direct-to-consumer', 'Fintech',
#        'Internet software &amp; services', 'Supply chain',
#        'Data management &amp; analytics', 'Edtech', 'Hardware',
#        'Consumer &amp; retail', 'Health', 'Auto &amp; transportation',
#        'Travel', 'Cybersecurity', 'Mobile &amp; telecommunications',
#        'Artificial Intelligence'], dtype=object)

# %%
df[' Industry'].value_counts()
# Out:
# Fintech                                252
# Internet software &amp; services       228
# E-commerce &amp; direct-to-consumer    109
# Health                                  95
# Artificial intelligence                 79
# Supply chain                            67
# Other                                   66
# Cybersecurity                           58
# Data management &amp; analytics         45
# Hardware                                40
# Mobile &amp; telecommunications         40
# Auto &amp; transportation               37
# Edtech                                  32
# Consumer &amp; retail                   31
# Travel                                  14
# Artificial Intelligence                 11
# Name:  Industry, dtype: int64

# %%
plt.figure(figsize=(15,6))
sns.countplot(df[' Industry'], data = df, 
             palette = 'hls')
plt.xticks(rotation = 90)
plt.show()

# %%
df[['Currency', 'Value']] = df[' Valuation($B)'].str.extract(r'([^\d]*)([\d,\.]+)')

# %%
df
# Out:
#                   Company  Valuation($B)  Date Joined        Country  \
# 0              ﻿ByteDance           $140   04-07-2017          China
# 1                  SpaceX           $127   12-01-2012  United States
# 2                   SHEIN           $100   07-03-2018          China
# 3                  Stripe            $95    1/23/2014  United States
# 4                   Canva            $40   01-08-2018      Australia
# ...                   ...            ...          ...            ...
# 1199          LeadSquared             $1    6/21/2022          India
# 1200            FourKites             $1    6/21/2022  United States
# 1201          VulcanForms             $1   07-05-2022  United States
# 1202          SingleStore             $1   07-12-2022  United States
# 1203  Unstoppable Domains             $1    7/27/2022  United States
#
#                City                             Industry  \
# 0           Beijing              Artificial intelligence
# ...

# %%
df[' Date Joined'] = pd.to_datetime(df[' Date Joined'])

# %%
df['Year'] = df[' Date Joined'].dt.year

# %%
df
# Out:
#                   Company  Valuation($B)  Date Joined        Country  \
# 0              ﻿ByteDance           $140   2017-04-07          China
# 1                  SpaceX           $127   2012-12-01  United States
# 2                   SHEIN           $100   2018-07-03          China
# 3                  Stripe            $95   2014-01-23  United States
# 4                   Canva            $40   2018-01-08      Australia
# ...                   ...            ...          ...            ...
# 1199          LeadSquared             $1   2022-06-21          India
# 1200            FourKites             $1   2022-06-21  United States
# 1201          VulcanForms             $1   2022-07-05  United States
# 1202          SingleStore             $1   2022-07-12  United States
# 1203  Unstoppable Domains             $1   2022-07-27  United States
#
#                City                             Industry  \
# 0           Beijing              Artificial intelligence
# ...

# %%
df['Year'].unique()
# Out:
# array([2017, 2012, 2018, 2014, 2019, 2016, 2021, 2022, 2015, 2020, 2013,
#        2011, 2007], dtype=int64)

# %%
df['Year'].value_counts()
# Out:
# 2021    524
# 2022    258
# 2020    106
# 2019    100
# 2018     97
# 2017     42
# 2015     34
# 2016     21
# 2014     12
# 2012      4
# 2013      3
# 2011      2
# 2007      1
# Name: Year, dtype: int64

# %%
plt.figure(figsize=(15,6))
sns.countplot(df['Year'], data = df, 
             palette = 'hls')
plt.xticks(rotation = 90)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1204 entries, 0 to 1203
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Company         1204 non-null   object
#  1    Valuation($B)  1204 non-null   object
#  2    Date Joined    1204 non-null   datetime64[ns]
#  3    Country        1204 non-null   object
#  4    City           1204 non-null   object
#  5    Industry       1204 non-null   object
#  6    Investors      1204 non-null   object
#  7   Currency        1204 non-null   object
#  8   Value           1204 non-null   object
#  9   Year            1204 non-null   int64
# dtypes: datetime64[ns](1), int64(1), object(8)
# memory usage: 94.2+ KB

# %%
df['Value'] = df['Value'].astype(float)

# %%
df.sort_values(by='Value', ascending=False, inplace=True)

# %%
plt.figure(figsize=(15,6))
sns.barplot(x = df['Company'].head(50), y = df['Value'].head(50), data = df, 
             palette = 'hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.lineplot(x = df['Company'].head(50), y = df['Value'].head(50), data = df, 
             palette = 'hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.scatterplot(x = df['Company'].head(50), y = df['Value'].head(50), data = df, 
             palette = 'hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.barplot(x = df[' Industry'], y = df['Value'], data = df, 
             palette = 'hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.lineplot(x = df[' Industry'], y = df['Value'], data = df, 
             palette = 'hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.scatterplot(x = df[' Industry'], y = df['Value'], data = df, 
             palette = 'hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.barplot(x = df['Year'], y = df['Value'], data = df, 
             palette = 'hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.lineplot(x = df['Year'], y = df['Value'], data = df, 
             palette = 'hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.scatterplot(x = df['Year'], y = df['Value'], data = df, 
             palette = 'hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.barplot(x = df[' Investors'].head(50), y = df['Value'].head(50), data = df, 
             palette = 'hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.lineplot(x = df[' Investors'].head(50), y = df['Value'].head(50), data = df, 
             palette = 'hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.scatterplot(x = df[' Investors'].head(50), y = df['Value'].head(50), data = df, 
             palette = 'hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.barplot(x = df[' Country'], y = df['Value'], data = df, 
             palette = 'hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.lineplot(x = df[' Country'], y = df['Value'], data = df, 
             palette = 'hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.scatterplot(x = df[' Country'], y = df['Value'], data = df, 
             palette = 'hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.barplot(x = df[' City'].head(50), y = df['Value'].head(50), data = df, 
             palette = 'hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.lineplot(x = df[' City'].head(50), y = df['Value'].head(50), data = df, 
             palette = 'hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.scatterplot(x = df[' City'].head(50), y = df['Value'].head(50), data = df, 
             palette = 'hls')
plt.xticks(rotation = 90)
plt.show()
