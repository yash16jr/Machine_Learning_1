# %%
import pandas as pd
import numpy as np
import seaborn as sns
import klib

# %% [raw]
# Who is the best team of all time
# Which teams dominated different eras of football
# What trends have there been in international football throughout the ages - home advantage, total goals scored, distribution of teams' strength etc
# Can we say anything about geopolitics from football fixtures - how has the number of countries changed, which teams like to play each other
# Which countries host the most matches where they themselves are not participating in
# How much, if at all, does hosting a major tournament help a country's chances in the tournament
# Which teams are the most active in playing friendlies and friendly tournaments - does it help or hurt them

# %%
df = pd.read_csv("C:/Users/Yash/Downloads/archive/results.csv", header = 0)

# %%
df.head()
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country  neutral
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False
# 4  Scotland    False

# %%
df.describe()
# Out:
#          home_score    away_score
# count  44353.000000  44353.000000
# mean       1.740559      1.178793
# std        1.748722      1.394580
# min        0.000000      0.000000
# 25%        1.000000      0.000000
# 50%        1.000000      1.000000
# 75%        2.000000      2.000000
# max       31.000000     21.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44353 entries, 0 to 44352
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        44353 non-null  object
#  1   home_team   44353 non-null  object
#  2   away_team   44353 non-null  object
#  3   home_score  44353 non-null  int64
#  4   away_score  44353 non-null  int64
#  5   tournament  44353 non-null  object
#  6   city        44353 non-null  object
#  7   country     44353 non-null  object
#  8   neutral     44353 non-null  bool
# dtypes: bool(1), int64(2), object(6)
# memory usage: 2.7+ MB

# %%
klib.data_cleaning(data = df)
# Out:
# Shape of cleaned data: (44353, 9) - Remaining NAs: 0
#
#
# Dropped rows: 0
#      of which 0 duplicates. (Rows (first 150 shown): [])
#
# Dropped columns: 0
#      of which 0 single valued.     Columns: []
# Dropped missing values: 0
# Reduced memory by at least: 1.53 MB (-55.64%)
#              date  home_team    away_team  home_score  away_score  \
# 0      1872-11-30   Scotland      England           0           0
# 1      1873-03-08    England     Scotland           4           2
# 2      1874-03-07   Scotland      England           2           1
# 3      1875-03-06    England     Scotland           2           2
# 4      1876-03-04   Scotland      England           3           0
# ...           ...        ...          ...         ...         ...
# 44348  2022-12-14   Thailand       Taiwan           0           1
# 44349  2022-12-14    Vietnam  Philippines           1           0
# 44350  2022-12-17    Croatia      Morocco           2           1
# ...

# %%
column = pd.to_datetime(df['date'])
range = column.max() - column.min()
range
# Out:
# Timedelta('54804 days 00:00:00')

# %%
df_sample = df.sample(n =  5000)

# %%
sns.jointplot(x= 'date' , y ='home_score' , data = df_sample)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 sns.jointplot(x= 'date' , y ='home_score' , data = df_sample)
#
# File ~\anaconda3\lib\site-packages\seaborn\axisgrid.py:2265, in jointplot(data, x, y, hue, kind, height, ratio, space, dropna, xlim, ylim, color, palette, hue_order, hue_norm, marginal_ticks, joint_kws, marginal_kws, **kwargs)
#    2262         marginal_kws.setdefault("fill", True)
#    2264     marginal_kws.setdefault("color", color)
# -> 2265     grid.plot_marginals(marg_func, **marginal_kws)
#    2267 elif kind.startswith("hist"):
#    2268
#    2269     # TODO process pair parameters for bins, etc. and pass
#    2270     # to both joint and marginal plots
#    2272     joint_kws.setdefault("color", color)
#
# File ~\anaconda3\lib\site-packages\seaborn\axisgrid.py:1877, in JointGrid.plot_marginals(self, func, **kwargs)
# ...

# %%
df_sample.describe()
# Out:
#         home_score   away_score
# count  5000.000000  5000.000000
# mean      1.724400     1.187800
# std       1.740876     1.404324
# min       0.000000     0.000000
# 25%       0.000000     0.000000
# 50%       1.000000     1.000000
# 75%       2.000000     2.000000
# max      24.000000    19.000000

# %% [markdown]
# ## Adding a winner col to the df

# %%
df['winner'] = df.apply(lambda x: x['home_team'] if x['home_score'] > x['away_score'] else (x['away_team'] if x['away_team'] > x['home_team'] else 'draw'), axis=1)

# %%
df.head()
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country  neutral    winner
# 0  Scotland    False      draw
# 1   England    False   England
# 2  Scotland    False  Scotland
# 3   England    False  Scotland
# 4  Scotland    False  Scotland
